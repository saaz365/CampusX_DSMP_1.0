# %%
#Q1. find which player has won most player of the match  -> in finals and qualifiers
#Q2. find which player has won most player of the match  -> in final , Qualifier 2,Qualifier 1 , Eliminator ,Semi-Final  
#Q3  how many matches each team has played
## in the this dataset i want to insert the  rank columns  the batsman on the bases on how many run they made

# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv("ipl.csv")
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
### find which player has won most player of the match  -> in finals and qualifiers

# potm = ipl [ (ipl["MatchNumber"] == 'Final') & (ipl["MatchNumber"] == 'Qualifier 2'   or  ipl["MatchNumber"] == 'Qualifier 1'  ) ]
            #  & ( ipl["Player_of_Match"]  )  ]


ipl[(ipl["MatchNumber"] == 'Final') &    ((ipl["MatchNumber"] == 'Qualifier 2'  ) & (  ipl["MatchNumber"] == 'Qualifier 1'  ) )]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
### find which player has won most player of the match  -> in final , Qualifier 2,Qualifier 1 only 


ipl2 = ipl[(ipl["MatchNumber"] == 'Final') | 
           (ipl["MatchNumber"] == 'Qualifier 2') | 
           (ipl["MatchNumber"] == 'Qualifier 1')]

pom_counts = ipl2["Player_of_Match"].value_counts()
pom_counts

# %%
# ipl2.value_counts()
pom_counts = ipl2["Player_of_Match"].value_counts()
pom_counts
# Out:
# Player_of_Match
# JJ Bumrah            2
# KA Pollard           2
# M Vijay              2
# YK Pathan            2
# SK Raina             2
# HH Pandya            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# SR Watson            1
# DA Miller            1
# F du Plessis         1
# VR Iyer              1
# JC Buttler           1
# BCJ Cutting          1
# Washington Sundar    1
# KV Sharma            1
# KH Pandya            1
# A Nehra              1
# DA Warner            1
# RG Sharma            1
# AB de Villiers       1
# UT Yadav             1
# V Sehwag             1
# MK Pandey            1
# Harbhajan Singh      1
# MS Bisla             1
# MEK Hussey           1
# CH Gayle             1
# A Kumble             1
# Name: count, dtype: int64

# %%
playoff_types = ['Final', 'Qualifier 1', 'Qualifier 2']
playoff_types
# Out:
# ['Final', 'Qualifier 1', 'Qualifier 2']

# %%
ipl2 = ipl[ipl["MatchNumber"].isin(playoff_types)]
ipl2
# Out:
#           ID          City        Date   Season  MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022        Final
# 1    1312199     Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197       Kolkata  2022-05-24     2022  Qualifier 1
# 74   1254117         Dubai  2021-10-15     2021        Final
# 75   1254116       Sharjah  2021-10-13     2021  Qualifier 2
# 77   1254114         Dubai  2021-10-10     2021  Qualifier 1
# 134  1237181           NaN  2020-11-10  2020/21        Final
# 135  1237180     Abu Dhabi  2020-11-08  2020/21  Qualifier 2
# 137  1237177           NaN  2020-11-05  2020/21  Qualifier 1
# 194  1181768     Hyderabad  2019-05-12     2019        Final
# 254  1136620        Mumbai  2018-05-27     2018        Final
# 314  1082650     Hyderabad  2017-05-21     2017        Final
# 315  1082649     Bangalore  2017-05-19     2017  Qualifier 2
# 317  1082647        Mumbai  2017-05-16     2017  Qualifier 1
# ...

# %%
playoff_types = ['Final', 'Qualifier 1', 'Qualifier 2']
ipl2 = ipl[ipl["MatchNumber"].isin(playoff_types)]
most_awarded = ipl2["Player_of_Match"].value_counts().head(1)
# Out:
# Player_of_Match
# HH Pandya       1
# F du Plessis    1
# TA Boult        1
# JJ Bumrah       1
# SR Watson       1
# KH Pandya       1
# BCJ Cutting     1
# RG Sharma       1
# MK Pandey       1
# KA Pollard      1
# MS Bisla        1
# M Vijay         1
# SK Raina        1
# A Kumble        1
# YK Pathan       1
# Name: count, dtype: int64

# %%
### find which player has won most player of the match  -> in final , Qualifier 2,Qualifier 1 , Eliminator ,Semi-Final  

ipl[ipl['MatchNumber'].str.isdigit()] ## this will make the data only having MatchNumber is digit no
# Out:
#           ID         City        Date   Season MatchNumber  \
# 4    1304116       Mumbai  2022-05-22     2022          70
# 5    1304115       Mumbai  2022-05-21     2022          69
# 6    1304114       Mumbai  2022-05-20     2022          68
# 7    1304113       Mumbai  2022-05-19     2022          67
# 8    1304112  Navi Mumbai  2022-05-18     2022          66
# ..       ...          ...         ...      ...         ...
# 945   335986      Kolkata  2008-04-20  2007/08           4
# 946   335985       Mumbai  2008-04-20  2007/08           5
# 947   335984        Delhi  2008-04-19  2007/08           3
# 948   335983   Chandigarh  2008-04-19  2007/08           2
# 949   335982    Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 4            Sunrisers Hyderabad                 Punjab Kings
# 5                 Delhi Capitals               Mumbai Indians
# 6            Chennai Super Kings             Rajasthan Royals
# ...

# %%
### find which player has won most player of the match  -> in final , Qualifier 2,Qualifier 1 , Eliminator ,Semi-Final  

ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
ipl2 = ipl[~ipl['MatchNumber'].str.isdigit()]
ipl2["Player_of_Match"].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %% [markdown]
# ---
# - ###  how many matches each team has played

# %%
ipl3 = ipl["Team1"] + ipl["Team2"]
team = pd.DataFrame( ipl3)
team.value_counts()
# Out:
# 0
# Chennai Super KingsMumbai Indians                     21
# Royal Challengers BangaloreKolkata Knight Riders      19
# Royal Challengers BangaloreChennai Super Kings        18
# Royal Challengers BangaloreMumbai Indians             18
# Chennai Super KingsRajasthan Royals                   17
#                                                       ..
# Royal Challengers BangaloreRising Pune Supergiants     1
# Sunrisers HyderabadPunjab Kings                        1
# Sunrisers HyderabadPune Warriors                       1
# Sunrisers HyderabadRising Pune Supergiant              1
# Sunrisers HyderabadRising Pune Supergiants             1
# Name: count, Length: 193, dtype: int64

# %%
# --------------------------------------------------
# SESSION 18 PRACTICE 03 AUG 26
# -----------------------------------------------------

#Q1. find which player has won most player of the match  -> in finals and qualifiers
#Q2. find which player has won most player of the match  -> in final , Qualifier 2,Qualifier 1 , Eliminator ,Semi-Final  
#Q3  how many matches each team has played
## in the this dataset i want to insert the  rank columns  the batsman on the bases on how many run they made

# %%
#Q1. find which player has won most player of the match  -> in finals and qualifiers
import numpy as np 
import pandas as pd 

ipl = pd.read_csv('ipl.csv')
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
ipl[(ipl['MatchNumber'] == 'Final') & (ipl['MatchNumber'] =='Qualifier')]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
#Q1. find which player has won most player of the match  -> in finals and qualifiers

ipl[~ipl['MatchNumber'].str.isdigit()][['Player_of_Match']].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# AB de Villiers       2
# A Kumble             2
# JJ Bumrah            2
# M Vijay              2
# YK Pathan            2
# SR Watson            2
# MK Pandey            2
# AD Russell           1
# AC Gilchrist         1
# A Nehra              1
# HH Pandya            1
# DE Bollinger         1
# DA Warner            1
# DA Miller            1
# BJ Hodge             1
# CH Gayle             1
# BCJ Cutting          1
# KH Pandya            1
# M Ntini              1
# KV Sharma            1
# MC Henriques         1
# MEK Hussey           1
# MM Patel             1
# KS Williamson        1
# JC Buttler           1
# Harbhajan Singh      1
# MS Dhoni             1
# MS Bisla             1
# MP Stoinis           1
# NM Coulter-Nile      1
# RM Patidar           1
# RR Pant              1
# RG Sharma            1
# RD Gaikwad           1
# SA Yadav             1
# Rashid Khan          1
# ...

# %%
#Q3  how many matches each team has played
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values( ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64
